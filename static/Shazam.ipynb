# %%
from ShazamAPI import Shazam

# def ShazamSong(file_path):

file_path = ('/users/seanmullins333/desktop/GodsPlan.mp3')
    
audio_file_path = file_path

mp3_file_content_to_recognize = open(audio_file_path, 'rb').read()

shazam = Shazam(mp3_file_content_to_recognize)

recognize_generator = shazam.recognizeSong()

try:
    result = next(recognize_generator)
    artist = result[1]['track']['subtitle']
    print(artist)
except (StopIteration, KeyError):
    print(None)
# Out:
# Drake

# %%
result
# Out:
# (11.0,
#  {'matches': [{'id': '642239292',
#     'offset': 3.021819335,
#     'timeskew': 0.00015509129,
#     'frequencyskew': -0.00016111135}],
#   'location': {'accuracy': 0.01},
#   'timestamp': 1684768967745,
#   'timezone': 'Europe/Moscow',
#   'track': {'layout': '5',
#    'type': 'MUSIC',
#    'key': '642239292',
#    'title': 'WONDERLAND (Hittin Two) (feat. 555lokey)',
#    'subtitle': 'GVM LILDREMILLER10',
#    'images': {'background': 'https://is2-ssl.mzstatic.com/image/thumb/AMCArtistImages126/v4/53/0a/92/530a927b-11f9-284d-fef9-6bc79ec37805/599691eb-8520-42a1-80a7-47c9639e7f0c_file_cropped.png/800x800cc.jpg',
#     'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music122/v4/a0/50/0a/a0500af1-28a4-58db-32ef-f447a7804f2d/artwork.jpg/400x400cc.jpg',
#     'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music122/v4/a0/50/0a/a0500af1-28a4-58db-32ef-f447a7804f2d/artwork.jpg/400x400cc.jpg',
#     'joecolor': 'b:000000p:fbfdfcs:c8c5c9t:c8cac9q:a09da1'},
# ...
